# %% [markdown]
# ## Import Libraries

# %%
from dotenv import load_dotenv
from datetime import datetime, timedelta

# %%
from keychain.config import AppConfig
from keychain.services.cryptography.client import CryptographyClient

# %% [markdown]
# ## Load `.env` files

# %%
load_dotenv("../../../../.env")

# %%
load_dotenv("../../../../db.env")

# %% [markdown]
# ## Initialize constants

# %%
app_config = AppConfig.get_or_create()

# %%
cryptography_client = CryptographyClient(app_config)

# %% [markdown]
# ## Main execution code

# %%
data = "test"

# %%
encrypted_data = cryptography_client.encrypt(data)

# %%
cryptography_client.decrypt(encrypted_data)
# assert data == cryptography_client.decrypt(encrypted_data)
