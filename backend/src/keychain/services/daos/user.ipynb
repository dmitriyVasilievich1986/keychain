# %% [markdown]
# ## Import libraries

# %%
from dotenv import load_dotenv

# %%
from keychain.config import AppConfig
from keychain.services.daos.user import UserDAO
from keychain.services.db_client import DBClient

# %% [markdown]
# ## Load `.env` files

# %%
load_dotenv("../../../../.env")

# %%
load_dotenv("../../../../db.env")

# %% [markdown]
# ## Initialize constants

# %%
app_config = AppConfig.get_or_create()

# %%
# app_config.db.host = "192.168.64.1"
db_client = DBClient(app_config)

# %%
user_dao = UserDAO(db_client)

# %% [markdown]
# ## Main code execution

# %%
await db_client.healthcheck()

# %%
# user = await user_dao.get_by_pk(1)
user = await user_dao.get_by_username("test")
